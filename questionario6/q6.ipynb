# %% [markdown]
# # Questão 1

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import normalized_mutual_info_score
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(201)
# create blobs
c = [(-2,1),(0,0),(4,6),(5,1),(6,12)]
n=300
data = make_blobs(n_samples=n, n_features=2, centers=c, cluster_std=1, random_state=50)
X = data[0]
labels = data[1]
plt.scatter(X[:,0], X[:,1], c=labels, cmap='viridis', s=50, alpha=0.9)
plt.show(True)

# %%
K = range(1,10)
best_k = 0
score = 0
new_score = 0

# considerando diversos valores de k
for k in K: 
    kmeans = KMeans(n_clusters=k)
    y_pred = kmeans.fit_predict(X)
    # A ordem correta é (rótulos_verdadeiros, rótulos_previstos)
    new_score = normalized_mutual_info_score(data[1], y_pred)
    if k==1:
        best_k = k
        new_score = score
    else:
        if new_score > score:
            best_k = k
            score = new_score

print("O melhor valor de k foi:", best_k, "com score:", score)
# Out:
# O melhor valor de k foi: 4 com score: 0.8875582355817716
# c:\ProgramData\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
k = best_k
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
y_km = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=y_km, cmap='viridis', s=50)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=100, alpha=0.5);
plt.xlim(-15,15)
plt.ylim(-15,15)
plt.title('K-means')
plt.show(True)
# Out:
# c:\ProgramData\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\ProgramData\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
# # Questão 2

# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score

# %%
def avaluate_silhouette(X):

    plt.figure(figsize=(12, 6))

    # Criando e treinando o modelo K-Means
    kmeans = KMeans(n_clusters=2, n_init='auto', random_state=42)
    y_kmeans = kmeans.fit_predict(X)
    score_kmeans = silhouette_score(X, y_kmeans)
    print(f'Coeficiente de Silhueta para K-Means: {score_kmeans:.3f}')

    # Visualizando o resultado do K-Means
    plt.subplot(1, 2, 1)
    plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis', s=50)
    plt.title(f'Resultado do K-Means\nSilhueta: {score_kmeans:.3f}')

    # Criando e treinando o modelo Agglomerative
    agg_clustering = AgglomerativeClustering(n_clusters=2, linkage='ward')
    y_agg = agg_clustering.fit_predict(X)
    score_agg = silhouette_score(X, y_agg)
    print(f'Coeficiente de Silhueta para Agglomerative: {score_agg:.3f}')

    # Visualizando o resultado do Agglomerative
    plt.subplot(1, 2, 2)
    plt.scatter(X[:, 0], X[:, 1], c=y_agg, cmap='viridis', s=50)
    plt.title(f'Agglomerative \nSilhueta: {score_agg:.3f}')
    
    plt.show()

# %%
for number_of_samples in [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]:
    X, y_true = make_circles(n_samples=800, factor=0.5, noise=0.05, random_state=42)

    plt.scatter(X[:, 0], X[:, 1], c=y_true, cmap='viridis', s=50)
    plt.title(f'Dados Originais Gerados com {number_of_samples} amostras')
    plt.show()

    avaluate_silhouette(X)
# Out:
# c:\ProgramData\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# Coeficiente de Silhueta para K-Means: 0.351
# Coeficiente de Silhueta para Agglomerative: 0.329
# c:\ProgramData\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# Coeficiente de Silhueta para K-Means: 0.351
# Coeficiente de Silhueta para Agglomerative: 0.329
# ...

# %%
print("Conclusão: K-means e Agglomerative não são adequados para realizar o agrupamento neste caso")
# Out:
# Conclusão: K-means e Agglomerative não são adequados para realizar o agrupamento neste caso
